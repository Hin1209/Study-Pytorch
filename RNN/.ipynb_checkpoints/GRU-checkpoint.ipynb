# %% [markdown]
# # Settings

# %%
# !pip install unidecode
import torch
import torch.nn as nn
from torch.autograd import Variable
import unidecode
import string
import random
import re
import time, math
# Out:
# Collecting unidecode
#   Downloading https://files.pythonhosted.org/packages/9e/25/723487ca2a52ebcee88a34d7d1f5a4b80b793f179ee0f62d5371938dfa01/Unidecode-1.2.0-py2.py3-none-any.whl (241kB)
#      |████████████████████████████████| 245kB 8.3MB/s eta 0:00:01
# Installing collected packages: unidecode
# Successfully installed unidecode-1.2.0

# %% [markdown]
# # Hyperparameters

# %%
num_epochs = 10000
print_every = 100
plot_every = 10
chunk_len = 200
embedding_size = 150
hidden_size = 100
batch_size = 1
num_layers = 2
lr = 0.002

# %% [markdown]
# # Data

# %%
all_characters = string.printable
n_characters = len(all_characters)
print(all_characters)
print('num_chars = ', n_characters)
# Out:
# 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#
# num_chars =  100

# %%
file = unidecode.unidecode(open('/content/drive/MyDrive/Colab Notebooks/input.txt').read())
file_len = len(file)
print('file_len = ', file_len)
# Out:
# file_len =  1115394

# %% [markdown]
# # Functions for text processing

# %%
def random_chunk():
  start_index = random.randint(0, file_len - chunk_len)
  end_index = start_index + chunk_len + 1
  return file[start_index:end_index]

print(random_chunk())
# Out:
# tian field,
# Streaming the ensign of the Christian cross
# Against black pagans, Turks, and Saracens:
# And toil'd with works of war, retired himself
# To Italy; and there at Venice gave
# His body to that plea

# %%
def char_tensor(string):
  tensor = torch.zeros(len(string)).long()
  for c in range(len(string)):
    tensor[c] = all_characters.index(string[c])
  return Variable(tensor).cuda()

print(char_tensor('ABCdef'))
# Out:
# tensor([36, 37, 38, 13, 14, 15], device='cuda:0')

# %%
def random_training_set():
  chunk = random_chunk()
  inp = char_tensor(chunk[:-1])
  target = char_tensor(chunk[1:])
  return inp, target

# %% [markdown]
# # RNN Class

# %%
class RNN(nn.Module):
  def __init__(self, input_size, embedding_size, hidden_size, output_size, num_layer=1):
    super(RNN, self).__init__()
    self.input_size = input_size
    self.hidden_size = hidden_size
    self.output_size = output_size
    self.num_layers = num_layers
    self.embedding_size = embedding_size

    self.encoder = nn.Embedding(input_size, embedding_size)
    self.rnn = nn.GRU(embedding_size, hidden_size, num_layers)
    self.decoder = nn.Linear(hidden_size, output_size)

  def forward(self, input, hidden):
    out = self.encoder(input.view(1, -1))
    out, hidden = self.rnn(out, hidden)
    out = self.decoder(out.view(batch_size, -1))

    return out, hidden

  def init_hidden(self):
    hidden = Variable(torch.zeros(num_layers, batch_size, hidden_size)).cuda()

    return hidden

model = RNN(n_characters, embedding_size, hidden_size, n_characters, num_layers).cuda()

# %%
inp = char_tensor("A")
print(inp)
hidden = model.init_hidden()
print(hidden.size())

out, hidden = model(inp, hidden)
print(out.size())
# Out:
# tensor([36], device='cuda:0')
# torch.Size([2, 1, 100])
# torch.Size([1, 100])

# %% [markdown]
# # Loss & Optimizer

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
loss_func = nn.CrossEntropyLoss()

# %% [markdown]
# # Test function

# %%
def test():
  start_str = "b"
  inp = char_tensor(start_str)
  hidden = model.init_hidden()
  x = inp

  print(start_str, end="")
  
  for i in range(200):
    output, hidden = model(x, hidden)

    output_dist = output.data.view(-1).div(0.8).exp()
    top_i = torch.multinomial(output_dist, 1)[0]
    predicted_char = all_characters[top_i]

    print(predicted_char, end="")
    
    x = char_tensor(predicted_char)

# %% [markdown]
# # Train

# %%
for i in range(num_epochs):
  total = char_tensor(random_chunk())
  inp = total[:-1]
  label = total[1:]
  hidden = model.init_hidden()

  loss = 0
  optimizer.zero_grad()
  for j in range(chunk_len - 1):
    x = inp[j]
    y_ = label[j].unsqueeze(0).type(torch.LongTensor).cuda()
    y, hidden = model(x, hidden)
    loss += loss_func(y, y_)

  loss.backward()
  optimizer.step()

  if i % 100 == 0:
    print("\n", loss/chunk_len, "\n")
    test()
    print("\n\n")
# Out:
#  tensor(4.5870, device='cuda:0', grad_fn=<DivBackward0>)
#
# '@)5*AA\i.uD
#
#
#
#  tensor(2.4408, device='cuda:0', grad_fn=<DivBackward0>)
#
# b-!L":S-he fhe thee nalked is sotherle igre he gaet,
# Egor lery thused sam sorer ase, thisete, ars rare pusar sand yot thoun thelem
# IAnd arer.
#
# E	}NEI:
# Tharl thralmessh ther,
# REy ofrve tor talleln maak
#
#
#
#  tensor(2.2928, device='cuda:0', grad_fn=<DivBackward0>)
#
# brogzortere ey in misline sull su noste math sall the an mabce lear!
# Bath pranlagt pt your and san id is:
# Wher a cinssat are,
# The thas jowwre an.
# Afith have prarh'd thatF your hour node tyar yous and
#
#
#
#  tensor(2.0368, device='cuda:0', grad_fn=<DivBackward0>)
#
# bde the whe bronent to mungon ould he home sin in, there I tue the houp ind? I the she the his in of gith made
# She mano of menind bim is and wirass this cnallowbporgherto ther.
#
# SELAVUSI PERILGRANE:
# Ha
#
#
#
#  tensor(2.0285, device='cuda:0', grad_fn=<DivBackward0>)
#
# blemes mone; here I to it what chear to tleis have panken, eptill nequade mare, thim the here entare darved and that the start,
# Ange.
#
# LENECSIO:
# Or hath, there
# detient in mut to I plow ame thus younl h
#
#
#
#  tensor(1.9783, device='cuda:0', grad_fn=<DivBackward0>)
#
# bCut sink bantler's it the the pisinder,
# And arres withen:
# My cread, was man, a pord to but is miness;
# A prown nome and fartion thiffes:
# And Pome say and be not rist have a my so cock, for sorn,
# Mone b
#
#
#
#  tensor(1.8566, device='cuda:0', grad_fn=<DivBackward0>)
#
# breen on's mubon of for:
# Then you scedss the kan I would for will my for.
#
# SThis spead hather of your in Sweems deadce;
# Whill in he be, of saw theo thus wis he it the was gy wiill you you many well and
#
#
#
#  tensor(1.8585, device='cuda:0', grad_fn=<DivBackward0>)
#
# bother have courser;
# O prive, have: the brice, this preach, at of that him, if myselret I are.
#
# TALOLENWEO:
# I farpard be he have the sreath,
# He was then night,
# O this hath cates une bith the to have
# Wh
#
#
#
#  tensor(1.9362, device='cuda:0', grad_fn=<DivBackward0>)
#
# bliend,
# And if you conure thee east with Pite exds'mas?
#
# Pbid.
# Fars to preack, you now and and the onour come.
#
# GAREN:
# Go prom an my thus picting the duts loth up to blemt
# Thy lain will best nich himpu
#
#
#
#  tensor(1.8918, device='cuda:0', grad_fn=<DivBackward0>)
#
# brat with's doult! with I sir of buter to; risees;
# Panibtens gueption to sugh there mart we woenther desay
# The beid and to men mome contaime on nexer to garster'd by my fizent
# Of thou heart thell he wi
#
#
#
#  tensor(1.6343, device='cuda:0', grad_fn=<DivBackward0>)
#
# b= this that sough and bust you beesly.
#
# BUTRESS:
# Coming not whone am beth'd our thee but these
# Led monet true the thee! I have bentience
# At saugao thee whittunce thisnon'd shall east wame. For what sh
#
#
#
#  tensor(1.8031, device='cuda:0', grad_fn=<DivBackward0>)
#
# bark let the not beace ranks
# Again of God-
# Look will he nother he will not knour him.
#
# LONTES:
# Whey breate were or beaten of the prime;
# Rousing wh Than as a hard he ever him the lighter for of who
# The
#
#
#
#  tensor(1.6579, device='cuda:0', grad_fn=<DivBackward0>)
#
# bleas the villing; this his so come,
# Let, such will man bid you are swair, he dimpmabes,
# That thy shall hebes it at do broness fathing sepers.
#
# PETRUST:
# Nows to your at word.
#
# BICLUCENTIO:
# No have man
#
#
#
#  tensor(1.8180, device='cuda:0', grad_fn=<DivBackward0>)
#
# best hopers here huss, there to bech
# By and the dentern's we word had the traucu ward
# Nose and brother somens, if that
# And mise, the mant as sware.
#
# LANDEEN VI:
# Good know poring I deserful sour, hespan
#
#
#
#  tensor(1.8074, device='cuda:0', grad_fn=<DivBackward0>)
#
# bord,
# Thou with hear this your at me what seep, my lave
# They fead with have loar thee thinted
# Have gently imy lied, for hive in thou by your gentle me with your seep-come, foo but
# light in I be wellain
#
#
#
#  tensor(1.6173, device='cuda:0', grad_fn=<DivBackward0>)
#
# bold,
# And the litt you aptial of that him hath the lage, ans before
# To hime he sunder war there.
# He the neven not your hore had than and times neat sered thy may him.
#
# LUCIO:
# Ut the ame of against I th
#
#
#
#  tensor(1.7909, device='cuda:0', grad_fn=<DivBackward0>)
#
# beed monistight him
# If I may denight the neuken not poopherefore wile theor the father,
# And wilt, not leep-do yet heor fight God my mark him,
# And by the mine: it naute of him malo.
#
# LUCIO:
# Ere is mard
#
#
#
#  tensor(1.7257, device='cuda:0', grad_fn=<DivBackward0>)
#
# bmand a shake.
# That in his gentlemenienst he were with
# Would thin! her am it the bay, put desee?
# I so so shal'd live!
#
# GEMENE:
# The chilt. Carrident of I world be dentlemens, live
# And thee know these to
#
#
#
#  tensor(1.6620, device='cuda:0', grad_fn=<DivBackward0>)
#
# bord, wemk; KINGom doughts love, iftitish.
#
# GRady thim make arry Mreast.
#
# DUCESTERY:
# Thou wild me in, mine before of make I wise seemine:
# With sundong hound with thou all srown will past:' and the was
#
#
#
#  tensor(1.6999, device='cuda:0', grad_fn=<DivBackward0>)
#
# breward of pere's the hath.
#
# First Nome the be in soul
# Than not enful duke that where dost's not to stirr?
# You me in he grace for me for can he happy:
# But for the duke and doth a grood our hath to my a
#
#
#
#  tensor(1.6927, device='cuda:0', grad_fn=<DivBackward0>)
#
# berrother the petpent,
# And the first hose live the dead,
# But whear fire the mapty perpunisercy
# My so sets disin'd.
#
# BATSMORY:
# No band.
#
# GRUST:
# O he was wonder'd securarage.
#
# DUCESTER:
# O he day and no,
#
#
#
#  tensor(1.7705, device='cuda:0', grad_fn=<DivBackward0>)
#
# bell, enven our crown, I'll the stay for thistres.
#
# WARWICHA:
# May with you to an thee betwent.
#
# ANDEN:
# Her here will show ofter to with in your with sint,
# Your fayer will this and of the man I was bani
#
#
#
#  tensor(1.5659, device='cuda:0', grad_fn=<DivBackward0>)
#
# brious to poim me.
#
# CIHEO:
# Even the ware see whose you say our curse to commors,
# And there to here there arm famertion of the made all withous of that in the gone!
#
# MERCUTIOLANUS:
# I gen astle of you. C
#
#
#
#  tensor(1.6021, device='cuda:0', grad_fn=<DivBackward0>)
#
# be the traite,
# I be brother so 'Nart that meard.
#
# QUEEN ELIZABETH:
# Shall be amore treath mine, there best scent you,
# My botthy was stack what you stied, my falous
# And facted to dead I must shall sweant
#
#
#
#  tensor(1.5141, device='cuda:0', grad_fn=<DivBackward0>)
#
# both us none of the power;
# And the furred where with when the pay be syephere on our diebers of promies.
#
# ENCALUS:
# A have of you wence you shave fare, and with to set think young lire,
# Dee what your be
#
#
#
#  tensor(1.5622, device='cuda:0', grad_fn=<DivBackward0>)
#
# bether to they all strangers,
# And world should by sha father with him offere to will to be not not
# Do day indan in not bragetin'd and life to pauly.
# Go your die
# Than life to the had the dayn,
# What to m
#
#
#
#  tensor(1.9098, device='cuda:0', grad_fn=<DivBackward0>)
#
# bem.
#
# PROMERLA:
# What you scarven his cound, thy longers swonder they in take the been your blood and thus cited
# As seek and from all mary's to priviliners!
#
# ISABELLA:
# The spea, to shall lase to your co
#
#
#
#  tensor(1.5673, device='cuda:0', grad_fn=<DivBackward0>)
#
# beit untage in the train,
# Whose as even the heir?
#
# MARIET:
# Thou sir. Buthing true wither Tirl. I say'd and for have it goings that proted
# What me content the trantuarding, if it,
# For a sily with it sen
#
#
#
#  tensor(1.5046, device='cuda:0', grad_fn=<DivBackward0>)
#
# brown repuchiof of the unclives live the steaks his seng well our quark.
#
# LUCIO:
# He was will for it must doth able love, must bestle true,
# Who is the fair should trept! shalt that as him words.
#
# SAPUTO
#
#
#
#  tensor(1.5756, device='cuda:0', grad_fn=<DivBackward0>)
#
# bact in the chie.
#
# POPRLIUS:
# Call I dight shall biteen my leance:
# That care of him sould been and and think body should begginaming unconter
# Would both eld and in the tike I disurnet.
#
# CORIO:
# Would mor
#
#
#
#  tensor(1.3050, device='cuda:0', grad_fn=<DivBackward0>)
#
# be all mistry now the
# be not the bost this my hall hereated
# And thy his fliether he him.
#
# HENRY BOLINGBROKE:
# Now, thee herself-sold he kneed of her
# Emplist them gonsed, we give, but
# remanish with his b
#
#
#
#  tensor(1.7977, device='cuda:0', grad_fn=<DivBackward0>)
#
# brought motion:
# For ever I has in the may bepours grour chance.
# Thy prothes you this with the trance to thy mant;
# Afty me cristy mannebour.
#
# LUCENTIO:
# And you your too make a more to yall this doth you
#
#
#
#  tensor(1.7950, device='cuda:0', grad_fn=<DivBackward0>)
#
# batves person
# In three by it that boys: before many
# For, lord his present thou whose commines, the complign Mart
# And till sheat, whuch a likenical hardward:
# But devil do bless that you bely for she was
#
#
#
#  tensor(1.7406, device='cuda:0', grad_fn=<DivBackward0>)
#
# but her!
# She that I so, I more, than have that all me.
#
# KING Hest:
# And strance, I ghet yethered, and and not should lied.
# Why, she compelooss a villain, not in the nead me, and hatper
# To his first Kate
#
#
#
#  tensor(1.2063, device='cuda:0', grad_fn=<DivBackward0>)
#
# brickrmen conder here
# Steck courge me in undersed the alt them pited
# In arm thee must now nelks bught poor sir.
#
# COMINIUS:
# No, to the lord on our ussing begin,
# To thee down and the prayer:
# Sweet my tat
#
#
#
#  tensor(1.2556, device='cuda:0', grad_fn=<DivBackward0>)
#
# bouding faster blood
# The stake for come of my speece him.
#
# MARETIUS:
# Where your so have sourn of not was
# hou a courn sorrow of Gaunes his had do my touch made;
# Stone, what be counster, while, gentleems
#
#
#
#  tensor(1.2903, device='cuda:0', grad_fn=<DivBackward0>)
#
# banious grathman.
#
# ANTAGUE:
# What with you this pity, and in this more of humble,
# The buither when the his peace.
#
# HOS IIA:
# The more a thing which first one, by him.
#
# POMPIOLAND:
# Norn en me 'pafive to h
#
#
#
#  tensor(1.5555, device='cuda:0', grad_fn=<DivBackward0>)
#
# ber the hear
# end with the exting who'er and madiel, the
# make and the respoctaw the coument surp.
#
# First CI Marding
# To my dear, as I new me a this little so,
# Deather go hear to the fail, I eftly with al
#
#
#
#  tensor(1.3803, device='cuda:0', grad_fn=<DivBackward0>)
#
# bend.
#
# PROSS:
# Come, I words, and do did him we word.
#
# CAPULET:
# I will not hear with serves, salk of what ise,
# Bother first a lords, the vide thee willows
# Our contrived he manishice and deather.
#
# KING R
#
#
#
#  tensor(1.6573, device='cuda:0', grad_fn=<DivBackward0>)
#
# by himself to be strace
# And be rest an it and thy one hather:
# An; boes, and he dart, them with seem scarrible.
#
# CAPULET:
# Well the stray my sons, O, I to, thy would not they truen
# our root: chares to sa
#
#
#
#  tensor(1.7186, device='cuda:0', grad_fn=<DivBackward0>)
#
# beows me upte footh:
# For this fair her to that bounted of his crown,
# A bring you queen wousours to my Varnerere:
# As and I 'patis' of your sissish
# Your have of did so good is aftinging of add of their h
#
#
#
#  tensor(1.6302, device='cuda:0', grad_fn=<DivBackward0>)
#
# bouded one and
# The comes, and I wirst: I would and dought
# To beforewell'd yous, therefore in thee.
#
# EDWARD II:
# For I must with thou bless gracate
# Will see like at a move,
# Were all you lond me:
# He was h
#
#
#
#  tensor(1.4957, device='cuda:0', grad_fn=<DivBackward0>)
#
# bed, and not not.
#
# DUKE VINCENTIO:
# Not him him with your edtlementer her: the neech
# Which shall sell news, not the heart of 'speak, breath the peace,
# The tre wind thou.
#
# DUKE VINCENTIO:
# My bleside thou
#
#
#
#  tensor(1.4870, device='cuda:0', grad_fn=<DivBackward0>)
#
# bant me an astent his soul-burn,
# Then thy not say, was our graith, what si
# Togeth will pity earthe in the riscompsion
# With fear to-morrow and will stay not,
# Let I how the am; what world, befoll for spa
#
#
#
#  tensor(1.6416, device='cuda:0', grad_fn=<DivBackward0>)
#
# bein an; and,
# And die bleath nor on out riving truction
# Lave,' remio, must of much the present?
#
# KING RICHARD III:
# And by this the securproke to fit.
#
# VOLUMBELLE:
# I say my shall have his life thy time,
#
#
#
#  tensor(1.6429, device='cuda:0', grad_fn=<DivBackward0>)
#
# bear she sent blad half.
#
# TRANIO:
# My so make it his are to and blass, sir.
#
# LEONT LARY IIAN:
# If an see I setter's with'd
# his every justage.
#
# LEONTES:
# My woold? I will here thou bedden and said.
#
# VOLUMN
#
#
#
#  tensor(1.4965, device='cuda:0', grad_fn=<DivBackward0>)
#
# beard are wife; O, engreats.
# Mort!
#
# ANTONIO:
# When with me hating be gone.
#
# ROMEO:
# Hear, whith from the what so way, I mistended wince in Nether:
# Apper heart, gone the woman do count bes hath son.
#
# PETE
#
#
#
#  tensor(1.5727, device='cuda:0', grad_fn=<DivBackward0>)
#
# bear's his sleep eye
# That that her the great concears with
# sealous than I feach: hell, help him I will is
# That here than this will not before but not and sab.
#
# GREMO:
# Deffther's will crown, to me by yo
#
#
#
#  tensor(1.7180, device='cuda:0', grad_fn=<DivBackward0>)
#
# but we at good the flower,
# And not no remage to darling that been up to Camried
# On of us the depart soul bust not las.
#
# MERCUTIO:
# How an leared not have and the woandy
# Do; sir, I shall part, and I will
#
#
#
#  tensor(1.3768, device='cuda:0', grad_fn=<DivBackward0>)
#
# batter posty seans.
# We can let you take a in proud a many: thy challen his babour?
#
# LUCENTIO:
#
# ANGELO:
# I know no greated him her did king be not bear
# To my gord, what, and be we about any give as
# you p
#
#
#
#  tensor(1.4073, device='cuda:0', grad_fn=<DivBackward0>)
#
# bounds the said.
#
# RICHARD II:
# Lord Froth thou thee, more forther.
#
# TRANIO:
# O mroke. Were lording eyes his ear shall beseech:
# You do the counsurely plaise is my soint to his love
# my state courn harvan a
#
#
#
#  tensor(1.8228, device='cuda:0', grad_fn=<DivBackward0>)
#
# ble, it nature to death,
# That said of his mild in fellow, as that?
#
# PETRUCHIO:
# My great than the destign your distaze;
# This the to sildued recessence all death of all.
#
# RICHARD IV:
# But, and more saciou
#
#
#
#  tensor(1.4593, device='cuda:0', grad_fn=<DivBackward0>)
#
# but they am not fortord
# Which we dance to being the true thee.
#
# Second Servant:
# Come from have more but entence and stamach the keep.
#
# LEONTES:
# Proke and affected, sir, we day his childress,
# Which shal
#
#
#
#  tensor(1.5415, device='cuda:0', grad_fn=<DivBackward0>)
#
# brave the stray; he their grace.
#
# GLOUCESTER:
# He line his aflaw.
#
# GRUMIO:
# Peraringha, let you shame, he shall so, is and when.
#
# POPRUTE:
# Here as him, grangs fidined.
#
# Post:
# Adit by ady have now.
#
# First
#
#
#
#  tensor(1.7425, device='cuda:0', grad_fn=<DivBackward0>)
#
# buse groans to be,
# That dop of your profound suck thy house contentbock nobld your body be saciant
# Where I have that being where's hath enough;
# But thou will was comfort a dark'd unto therefore that;
# A
#
#
#
#  tensor(1.6151, device='cuda:0', grad_fn=<DivBackward0>)
#
# but
# Thou thereatains hearliants life,
# I awell up come with a bed.
#
# Servant:
# You dight, death, but she'll spied,
# And me must when delive.
#
# MENENIUS:
# Give a sout exceat,
# Be me will nareting to be this, b
#
#
#
#  tensor(1.3064, device='cuda:0', grad_fn=<DivBackward0>)
#
# but sise.
#
# ROMEO:
# Come, and you all my rucise lose, if himself blood,
# To blood, sir, stock'd, do his best art more had these past.
#
# WARWICK:
# Hold shall my love upon heaven of damely and bise is me from
#
#
#
#  tensor(1.3669, device='cuda:0', grad_fn=<DivBackward0>)
#
# bel prince, and was with this
# coming to the king so till to to
# do so no have in thine is aquels.
#
# LADY IF:
# God father, I was taster and love.
#
# DUKE VINCENTIO:
# Ad with undeeds, sir, and then promise.
# Sa
#
#
#
#  tensor(1.6480, device='cuda:0', grad_fn=<DivBackward0>)
#
# bock of it race of the rewell.
#
# DUKE VINCENTIO:
# Ay so father, never pare you in my jurfont
# Upon my noble the pature.
#
# ROMEO:
# I a for Julital patient 'RINCENTIO:
# Where it are the Dothing may undor to th
#
#
#
#  tensor(1.5294, device='cuda:0', grad_fn=<DivBackward0>)
#
# be craves thee end to teath to see expersed of counter'd,
# Thiy his sovering refore gone.
#
# Second Lady:
# When with him, with all hem off while the great
# She will and be so be then generest as the seer, s
#
#
#
#  tensor(1.4231, device='cuda:0', grad_fn=<DivBackward0>)
#
# beon the prison, I that he
# so prays me she hands a house the bady to with thou.
#
# CAMILLO:
# I preteth helps deedended thing but the indeed;
# And show te as are be the more hope:
# My grace not my present of
#
#
#
#  tensor(1.1940, device='cuda:0', grad_fn=<DivBackward0>)
#
# beliend and shows on this please,
# But my many for any joins it their now,
# By more nows him: you with the porture out.
#
# FRIAR LAURENCE:
# I have confest, it two more a man to with gentleman:
# Master, 'tis
#
#
#
#  tensor(1.5642, device='cuda:0', grad_fn=<DivBackward0>)
#
# bracensest and me but you make your sea: my death.
#
# GLOUCESTER:
# He of her tempar was not have but cerse hand
# Should come to sauck livers of not must love the confed:
# Ay!
#
# AUTOLYCUS:
# Hard, the consenty
#
#
#
#  tensor(1.4197, device='cuda:0', grad_fn=<DivBackward0>)
#
# both.
#
# DORCANUS:
# Now that pations; I must thee, shalt like reins he heaven;
# Than whuld prome, who death mercy;
# And she know thy sproscent.
#
# ANGELO:
# What waintens to recless myself he father, my word,
# B
#
#
#
#  tensor(1.6639, device='cuda:0', grad_fn=<DivBackward0>)
#
# bene to have at me,
# But not of you be home, and my good think your bust.
#
# GREMIO:
# Not consulunces of thing king the word my great
# And countest she can friend against much and Angelo with stigue upon
# ne
#
#
#
#  tensor(1.3574, device='cuda:0', grad_fn=<DivBackward0>)
#
# be stoot so manish'd my hath blook of hands
# A poor lords, in king father of your peace,
# Have but what be leave of I aluch is you't is is the vitice?
# Terciant, it sir, Richard, sir, my thousore the cloy
#
#
#
#  tensor(1.7495, device='cuda:0', grad_fn=<DivBackward0>)
#
# bided my ports, seem'd keep.
# Boot, not, the Vather enemy not revender.
# A may from the poisord myself.
#
# AUTOLYCUS:
# But we command when he have your faste
# Apteans to true this sword again,
# Whom that are
#
#
#
#  tensor(1.3566, device='cuda:0', grad_fn=<DivBackward0>)
#
# boung, less such merry,
# Liest the lust you strongand young brother's eyes and plage
# If when let in leave here.
#
# HORTENSA:
# My knee if it of Lord God fill they shall roul,
# Or betten of him compers they d
#
#
#
#  tensor(1.5584, device='cuda:0', grad_fn=<DivBackward0>)
#
# bell, for mine, we
# consude the till will with our love
# My beat the shame our soldren onelany.
#
# First a father?
# My very that by contague.' Think the soull.
#
# ANTOSBY:
# Good Colose of a scale of the son,
# T
#
#
#
#  tensor(1.4007, device='cuda:0', grad_fn=<DivBackward0>)
#
# by will talk,
# That words with the world law, where is the book'd,
# And say, by ri, the river, thee up of the have quickly
# Scall tell my great dange, look on your all about than the are:
# Eirtain the cong
#
#
#
#  tensor(1.2868, device='cuda:0', grad_fn=<DivBackward0>)
#
# batters be, and enter'd reptrenger.
#
# LADYCAND:
# I sous to the rust this gractions.
#
# MERCUTIO:
# You has as eyes and be nor dones,
# That mucieldly to righs a soungland is lay,
# Than I take intures, to the co
#
#
#
#  tensor(1.4635, device='cuda:0', grad_fn=<DivBackward0>)
#
# be years.
#
# MERCUSTI:
# Unless not bout:
# From God will not them your counte which nor lief,
# And speak to Juliet?
#
# DUKE OF YORK:
# And be is the present Salicians and hid his shall from hights and precefted
#
#
#
#
#  tensor(1.4495, device='cuda:0', grad_fn=<DivBackward0>)
#
# boy,
# Ricanne the ear the solved thought in the wear'd and and let untain not to-let;
#
# GLOUCESTER:
# Sir, he pecairred royhard at fent shapes,
# The greate, I havens to shalt be from thy cload in yeary pain
#
#
#
#  tensor(1.4999, device='cuda:0', grad_fn=<DivBackward0>)
#
# b, strength soldiers, how
# To you will light do, sir, if youngrage bloody, my name;
# Even eye spoks a tent with the londer?
#
# LEONTES:
# What I can Pompertion
# The send a gentle reparting Timest in myself to
#
#
#
#  tensor(1.6675, device='cuda:0', grad_fn=<DivBackward0>)
#
# be her likinalent when
# The sing constant to powers and long slafe,
# Which is my since the like you any.
# O, my hand, as you hasted in youth?
#
# YORK:
# O, who for his balk your foor cold the mantent the died
#
#
#
#  tensor(1.4814, device='cuda:0', grad_fn=<DivBackward0>)
#
# bed and marry.
#
# HENRY BOLINGBROKE:
# Is it not therearly lord a so far in thee;--
# As I she's me something so'er we shall not of him.
#
# KING HENRY VI
# Come, that you hath the mide of the cannot sort--
# Sir,
#
#
#
#  tensor(1.5307, device='cuda:0', grad_fn=<DivBackward0>)
#
# bout of constrake-maition.
#
# QUEENN ELIZABETH:
# I am doth God, undong off-age grave him
# Qown with conveing but the prongry?
#
# PAULINIA:
# But a manture with a brother beauty--
# But the lest vantom from raugh
#
#
#
#  tensor(1.3838, device='cuda:0', grad_fn=<DivBackward0>)
#
# by Get the worst are be his true tongue!
#
# KING RICHARD III:
# Strike you have on how in grief.
# Thy are my been one up man will beater's sleep were me;
# There's Rome you it?
#
# KING EDWARD IV:
# Where is some
#
#
#
#  tensor(1.2867, device='cuda:0', grad_fn=<DivBackward0>)
#
# by thou linged make shalled to me
# That you her say, let they say you are tho would life
# As thing found of done, I masting, the may him.
#
# Be your gone, you news--
# Sir, I will not in my sween I hath be w
#
#
#
#  tensor(1.7334, device='cuda:0', grad_fn=<DivBackward0>)
#
# bance could be battle.
#
# HASTINGS:
# You had very weal pervant any than
# there in here in accuse, and accore.
#
# First Murderer:
# Not our more hath severdy besever than you wealth.
#
# CORIOLANUS:
# O love dead ha
#
#
#
#  tensor(2.2824, device='cuda:0', grad_fn=<DivBackward0>)
#
# bcounch too!
#
# GLOUCESTER:
# Thou cannot conceive the true,
# Alate are like, grievous, I may well
# Jot in the lover, many the fall to his words to the pody are honour humble of his hang,
# In jouse thou aster
#
#
#
#  tensor(1.5815, device='cuda:0', grad_fn=<DivBackward0>)
#
# be your easance: it note of the dare.
#
# BENVOLIO:
# How not am it before the king.
#
# GLOUCESTER:
# Happina, and be make me, be sue to Kate those.
#
# CAMISLIIUS:
# I, Gold within this seen for who poor capter wou
#
#
#
#  tensor(1.4331, device='cuda:0', grad_fn=<DivBackward0>)
#
# be bless of woo as this away.
# A more and been him of my soul
# To life the call a voiced and of Lances, boy,
# That his enhure charge, we are your would go to the matter'd to seeks, and
# That crown the fort
#
#
#
#  tensor(1.9457, device='cuda:0', grad_fn=<DivBackward0>)
#
# be best thee that your liveants:
# I present his more than which should winty laishal,
# Now think the soul to first forth.
# Canter'd I had yeed royal be hand o'er children:
# Why, love not delintter some har
#
#
#
#  tensor(1.6581, device='cuda:0', grad_fn=<DivBackward0>)
#
# be'ly partion untory!
# The slain than he's drown shall gentleman
# And leave it it of the secious,
# With stand any me them bent carral not that hearge
# As the wine, and flacked shamely else,
# And all besor.
#
#
#
#  tensor(1.6464, device='cuda:0', grad_fn=<DivBackward0>)
#
# be me at me as your comess drught:
# In me his suatress, all my treasural
# But thee arm our lovelt was cardied and unto and it a
# leed thellers, though the this are was thee not to some that
# Ullains see sh
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-3006c8e86287> in <module>()
#      13     loss += loss_func(y, y_)
#      14
# ---> 15   loss.backward()
#      16   optimizer.step()
#      17
#
# /usr/local/lib/python3.7/dist-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     219                 retain_graph=retain_graph,
#     220                 create_graph=create_graph)
# --> 221         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     222
#     223     def register_hook(self, hook):
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     130     Variable._execution_engine.run_backward(
#     131         tensors, grad_tensors_, retain_graph, create_graph,
# --> 132         allow_unreachable=True)  # allow_unreachable flag
#     133
#     134
#
# KeyboardInterrupt:
